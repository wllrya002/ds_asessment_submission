# %% [markdown]
# <H2> INTRODUCTION

# %% [markdown]
#  - This script reads in the required files from AWS (for the challenge) and exports it to the local environment for usage.
#  - Link to CPT DS challenge: https://github.com/cityofcapetown/ds_code_challenge
#  - Submission for the CCT Data Scientist role, July 2022.
#  - Compiler/submitter: Ryan Williams

# %% [markdown]
# <H3> IMPORT DEPENDANCIES

# %%
import json
import botocore
import boto3
import io
from io import BytesIO
import pandas as pd
import gzip
import geopandas as gpd
from area import area
import shapely
from shapely.geometry import Polygon
import datetime

# %% [markdown]
# <h3> SETUP CREDENTIALS AND AWS SESSION

# %%
# Load secrets file:
with open('secrets.json') as f:
    json_data = json.load(f)
aws_access_key_id=json_data['s3']['access_key']
aws_secret_access_key=json_data['s3']['secret_key']
region='af-south-1'

# aws_access_key_id,aws_secret_access_key,region #Debug.

# %%
s3_client = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
    region_name=region
)

# %%
bucket_name = 'cct-ds-code-challenge-input-data'

# %% [markdown]
# ---

# %% [markdown]
# <h3> READ IN FILES AND EXPORT

# %% [markdown]
# **Read the "sr.csv.gz" file**

# %%
response = s3_client.get_object(Bucket=bucket_name, Key='sr.csv.gz')
gzipfile = gzip.GzipFile(fileobj=BytesIO(response['Body'].read()))
sr=pd.read_csv(BytesIO(gzipfile.read()))
sr
# Out:
#         Unnamed: 0  notification_number  reference_number  \
# 0                0            400583534      9.109492e+09
# 1                1            400555043      9.108995e+09
# 2                2            400589145      9.109614e+09
# 3                3            400538915      9.108601e+09
# 4                4            400568554               NaN
# ...            ...                  ...               ...
# 941629      941629           1016508425      9.109974e+09
# 941630      941630           1016508432      9.109975e+09
# 941631      941631           1016508434      9.109975e+09
# 941632      941632           1016508442      9.109975e+09
# 941633      941633           1016508443      9.109975e+09
#
#                creation_timestamp       completion_timestamp  \
# 0       2020-10-07 06:55:18+02:00  2020-10-08 15:36:35+02:00
# 1       2020-07-09 16:08:13+02:00  2020-07-14 14:27:01+02:00
# 2       2020-10-27 10:21:59+02:00  2020-10-28 17:48:15+02:00
# 3       2020-03-19 06:36:06+02:00  2021-03-29 20:34:19+02:00
# 4       2020-08-25 09:48:42+02:00  2020-08-31 08:41:13+02:00
# ...                           ...                        ...
# 941629  2020-12-31 23:49:38+02:00  2021-01-11 11:54:42+02:00
# 941630  2020-12-31 23:31:11+02:00  2021-01-04 11:46:28+02:00
# 941631  2020-12-31 23:58:21+02:00  2021-01-01 00:01:08+02:00
# 941632  2020-12-31 23:41:57+02:00  2021-01-05 15:59:24+02:00
# 941633  2020-12-31 23:54:09+02:00  2021-02-23 10:38:21+02:00
#
#                  directorate                       department  \
# 0             URBAN MOBILITY  Roads Infrastructure Management
# 1             URBAN MOBILITY  Roads Infrastructure Management
# 2             URBAN MOBILITY  Roads Infrastructure Management
# 3             URBAN MOBILITY  Roads Infrastructure Management
# 4             URBAN MOBILITY  Roads Infrastructure Management
# ...                      ...                              ...
# 941629  WATER AND SANITATION            Distribution Services
# 941630  WATER AND SANITATION            Distribution Services
# 941631  WATER AND SANITATION            Distribution Services
# 941632  WATER AND SANITATION              Commercial Services
# 941633  WATER AND SANITATION              Commercial Services
#
#                            branch                          section  \
# 0                RIM Area Central             District: Blaauwberg
# 1                   RIM Area East         District : Somerset West
# 2                   RIM Area East         District : Somerset West
# 3                  RIM Area North             District : Bellville
# 4                  RIM Area South               District : Athlone
# ...                           ...                              ...
# 941629               Reticulation  Reticulation Water Distribution
# 941630               Reticulation                              NaN
# 941631               Reticulation                              NaN
# 941632  Customer Services (Water)                 Meter Management
# 941633  Customer Services (Water)                 Meter Management
#
#                           code_group                                    code  \
# 0       TD Customer complaint groups  Pothole&Defect Road Foot Bic Way/Kerbs
# 1       TD Customer complaint groups                Manhole Cover/Gully Grid
# 2       TD Customer complaint groups                Manhole Cover/Gully Grid
# 3       TD Customer complaint groups              Paint Markings Lines&Signs
# 4       TD Customer complaint groups  Pothole&Defect Road Foot Bic Way/Kerbs
# ...                              ...                                     ...
# 941629                         WATER                           Leak at Valve
# 941630                         SEWER                 Sewer: Blocked/Overflow
# 941631                         WATER                              Burst Pipe
# 941632       WATER MANAGEMENT DEVICE                            No Water WMD
# 941633                         WATER          Leak at Water Meter / Stopcock
#
#        cause_code_group         cause_code   official_suburb   latitude  \
# 0            Road (RCL)      Wear and tear  MONTAGUE GARDENS -33.872839
# 1            Road (RCL)          Vandalism     SOMERSET WEST -34.078916
# 2            Road (RCL)          Vandalism            STRAND -34.102242
# 3         Road Markings      Wear and tear        RAVENSMEAD -33.920019
# 4            Road (RCL)  Surfacing failure         CLAREMONT -33.987400
# ...                 ...                ...               ...        ...
# 941629              NaN                NaN         WOODSTOCK -33.931571
# 941630          General    Foreign Objects      FISANTEKRAAL -33.783246
# 941631              NaN                NaN               NaN        NaN
# 941632              NaN                NaN           WESBANK -33.971099
# 941633              NaN                NaN           BIZWENI -34.088078
#
#         longitude
# 0       18.522488
# 1       18.848940
# 2       18.821116
# 3       18.607209
# 4       18.453760
# ...           ...
# 941629  18.452159
# 941630  18.716554
# 941631        NaN
# 941632  18.659831
# 941633  18.862550
#
# [941634 rows x 16 columns]

# %%
# Specify date and name and export the file.
date_time=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
name=date_time+'_service_requests.csv'

sr.to_csv(name)

# %% [markdown]
# **Read the "sr_hex.csv.gz" file**

# %%
response = s3_client.get_object(Bucket=bucket_name, Key='sr_hex.csv.gz')
gzipfile = gzip.GzipFile(fileobj=BytesIO(response['Body'].read()))
sr_hex=pd.read_csv(BytesIO(gzipfile.read()))
sr_hex
# Out:
#         notification_number  reference_number         creation_timestamp  \
# 0                 400583534      9.109492e+09  2020-10-07 06:55:18+02:00
# 1                 400555043      9.108995e+09  2020-07-09 16:08:13+02:00
# 2                 400589145      9.109614e+09  2020-10-27 10:21:59+02:00
# 3                 400538915      9.108601e+09  2020-03-19 06:36:06+02:00
# 4                 400568554               NaN  2020-08-25 09:48:42+02:00
# ...                     ...               ...                        ...
# 941629           1016508425      9.109974e+09  2020-12-31 23:49:38+02:00
# 941630           1016508432      9.109975e+09  2020-12-31 23:31:11+02:00
# 941631           1016508434      9.109975e+09  2020-12-31 23:58:21+02:00
# 941632           1016508442      9.109975e+09  2020-12-31 23:41:57+02:00
# 941633           1016508443      9.109975e+09  2020-12-31 23:54:09+02:00
#
#              completion_timestamp           directorate  \
# 0       2020-10-08 15:36:35+02:00        URBAN MOBILITY
# 1       2020-07-14 14:27:01+02:00        URBAN MOBILITY
# 2       2020-10-28 17:48:15+02:00        URBAN MOBILITY
# 3       2021-03-29 20:34:19+02:00        URBAN MOBILITY
# 4       2020-08-31 08:41:13+02:00        URBAN MOBILITY
# ...                           ...                   ...
# 941629  2021-01-11 11:54:42+02:00  WATER AND SANITATION
# 941630  2021-01-04 11:46:28+02:00  WATER AND SANITATION
# 941631  2021-01-01 00:01:08+02:00  WATER AND SANITATION
# 941632  2021-01-05 15:59:24+02:00  WATER AND SANITATION
# 941633  2021-02-23 10:38:21+02:00  WATER AND SANITATION
#
#                              department                     branch  \
# 0       Roads Infrastructure Management           RIM Area Central
# 1       Roads Infrastructure Management              RIM Area East
# 2       Roads Infrastructure Management              RIM Area East
# 3       Roads Infrastructure Management             RIM Area North
# 4       Roads Infrastructure Management             RIM Area South
# ...                                 ...                        ...
# 941629            Distribution Services               Reticulation
# 941630            Distribution Services               Reticulation
# 941631            Distribution Services               Reticulation
# 941632              Commercial Services  Customer Services (Water)
# 941633              Commercial Services  Customer Services (Water)
#
#                                 section                    code_group  \
# 0                  District: Blaauwberg  TD Customer complaint groups
# 1              District : Somerset West  TD Customer complaint groups
# 2              District : Somerset West  TD Customer complaint groups
# 3                  District : Bellville  TD Customer complaint groups
# 4                    District : Athlone  TD Customer complaint groups
# ...                                 ...                           ...
# 941629  Reticulation Water Distribution                         WATER
# 941630                              NaN                         SEWER
# 941631                              NaN                         WATER
# 941632                 Meter Management       WATER MANAGEMENT DEVICE
# 941633                 Meter Management                         WATER
#
#                                           code cause_code_group  \
# 0       Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)
# 1                     Manhole Cover/Gully Grid       Road (RCL)
# 2                     Manhole Cover/Gully Grid       Road (RCL)
# 3                   Paint Markings Lines&Signs    Road Markings
# 4       Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)
# ...                                        ...              ...
# 941629                           Leak at Valve              NaN
# 941630                 Sewer: Blocked/Overflow          General
# 941631                              Burst Pipe              NaN
# 941632                            No Water WMD              NaN
# 941633          Leak at Water Meter / Stopcock              NaN
#
#                cause_code   official_suburb   latitude  longitude  \
# 0           Wear and tear  MONTAGUE GARDENS -33.872839  18.522488
# 1               Vandalism     SOMERSET WEST -34.078916  18.848940
# 2               Vandalism            STRAND -34.102242  18.821116
# 3           Wear and tear        RAVENSMEAD -33.920019  18.607209
# 4       Surfacing failure         CLAREMONT -33.987400  18.453760
# ...                   ...               ...        ...        ...
# 941629                NaN         WOODSTOCK -33.931571  18.452159
# 941630    Foreign Objects      FISANTEKRAAL -33.783246  18.716554
# 941631                NaN               NaN        NaN        NaN
# 941632                NaN           WESBANK -33.971099  18.659831
# 941633                NaN           BIZWENI -34.088078  18.862550
#
#         h3_level8_index
# 0       88ad360225fffff
# 1       88ad36d5e1fffff
# 2       88ad36d437fffff
# 3       88ad361133fffff
# 4       88ad361709fffff
# ...                 ...
# 941629  88ad361547fffff
# 941630  88ad3656d7fffff
# 941631                0
# 941632  88ad36c49bfffff
# 941633  88ad36d517fffff
#
# [941634 rows x 16 columns]

# %%
# Specify date and name and export the file.
date_time=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
name=date_time+'_service_requests_8hex.csv'

sr_hex.to_csv(name)

# %% [markdown]
# **Read the "sr_hex_truncated.csv" file**

# %%
response = s3_client.get_object(Bucket=bucket_name, Key='sr_hex_truncated.csv')
sr_hex_trunk = pd.read_csv(response.get("Body"))
sr_hex_trunk
# Out:
#         notification_number  reference_number         creation_timestamp  \
# 0                 400538915      9.108601e+09  2020-03-19 06:36:06+02:00
# 1                 400531832      9.108432e+09  2020-02-18 07:28:11+02:00
# 2                 400538969      9.108603e+09  2020-03-19 08:19:43+02:00
# 3                 400525122               NaN  2020-01-22 14:18:42+02:00
# 4                 400539785               NaN  2020-03-24 09:00:38+02:00
# ...                     ...               ...                        ...
# 254799           1015749632      9.108652e+09  2020-03-31 22:50:30+02:00
# 254800           1015749633      9.108652e+09  2020-03-31 23:10:38+02:00
# 254801           1015749643               NaN  2020-03-31 23:12:43+02:00
# 254802           1015749644               NaN  2020-03-31 23:12:12+02:00
# 254803           1015749645               NaN  2020-03-31 23:31:07+02:00
#
#              completion_timestamp             directorate  \
# 0       2021-03-29 20:34:19+02:00          URBAN MOBILITY
# 1       2020-02-25 07:48:44+02:00          URBAN MOBILITY
# 2       2021-03-09 20:59:23+02:00                     NaN
# 3                             NaN    WATER AND SANITATION
# 4       2022-02-21 07:27:11+02:00          URBAN MOBILITY
# ...                           ...                     ...
# 254799  2020-04-03 08:21:29+02:00                  ENERGY
# 254800  2020-04-02 08:54:34+02:00  URBAN WASTE MANAGEMENT
# 254801  2020-09-12 11:55:39+02:00                  ENERGY
# 254802  2020-04-03 08:18:15+02:00                  ENERGY
# 254803  2020-04-08 15:45:27+02:00                 FINANCE
#
#                                      department                       branch  \
# 0               Roads Infrastructure Management               RIM Area North
# 1               Roads Infrastructure Management               RIM Area South
# 2                                           NaN                          NaN
# 3                         Distribution Services                 Reticulation
# 4               Roads Infrastructure Management               RIM Area North
# ...                                         ...                          ...
# 254799  Electricity Generation and Distribution  Enterprise Asset Management
# 254800                   Solid Waste Management                    Cleansing
# 254801  Electricity Generation and Distribution  Enterprise Asset Management
# 254802  Electricity Generation and Distribution  Enterprise Asset Management
# 254803                                  Revenue               Debtors & Cash
#
#                                section                        code_group  \
# 0                 District : Bellville      TD Customer complaint groups
# 1                   District : Athlone      TD Customer complaint groups
# 2                                  NaN      TD Customer complaint groups
# 3           Reticulation WW Conveyance      TD Customer complaint groups
# 4                 District : Bellville      TD Customer complaint groups
# ...                                ...                               ...
# 254799           CTE Distribution East  ELECTRICITY TECHNICAL COMPLAINTS
# 254800                             NaN                       SOLID WASTE
# 254801          CTE Distribution South  ELECTRICITY TECHNICAL COMPLAINTS
# 254802          CTE Distribution South  ELECTRICITY TECHNICAL COMPLAINTS
# 254803  Revenue CIC Management : North                           REVENUE
#
#                                           code cause_code_group  \
# 0                   Paint Markings Lines&Signs    Road Markings
# 1                   Paint Markings Lines&Signs       Road (RCL)
# 2       Pothole&Defect Road Foot Bic Way/Kerbs       Road (RCL)
# 3       Pothole&Defect Road Foot Bic Way/Kerbs         Sidewalk
# 4                     Manhole Cover/Gully Grid              NaN
# ...                                        ...              ...
# 254799                                No Power  Point of Supply
# 254800                         Illegal Dumping              NaN
# 254801                                No Power              NaN
# 254802                         PPM Faulty Mode              NaN
# 254803                Housing Tenant Transfers              NaN
#
#                          cause_code official_suburb   latitude  longitude  \
# 0                     Wear and tear      RAVENSMEAD -33.920019  18.607209
# 1                     Wear and tear      BRIDGETOWN -33.959023  18.535687
# 2                      Base failure        RICHWOOD -33.835900  18.541292
# 3       Underground service failure     GRASSY PARK -34.056338  18.494952
# 4                               NaN         FLORIDA -33.922589  18.594716
# ...                             ...             ...        ...        ...
# 254799                       Faulty      RAVENSMEAD -33.926694  18.603812
# 254800                          NaN         RETREAT -34.057951  18.485519
# 254801                          NaN       CLAREMONT -33.981874  18.480294
# 254802                          NaN       ROCKLANDS -34.062772  18.602571
# 254803                          NaN   LAVENDER HILL -34.071826  18.486385
#
#         h3_level8_index
# 0       88ad361133fffff
# 1       88ad3610e9fffff
# 2       88ad360337fffff
# 3       88ad368d11fffff
# 4       88ad3611e1fffff
# ...                 ...
# 254799  88ad3611edfffff
# 254800  88ad368d1bfffff
# 254801  88ad361761fffff
# 254802  88ad3688a5fffff
# 254803  88ad368c2dfffff
#
# [254804 rows x 16 columns]

# %%
# Specify date and name and export the file.
date_time=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
name=date_time+'_service_requests_8hex_truncated.csv'

sr_hex_trunk.to_csv(name)

# %% [markdown]
# **Read the "city-hex-polygons-8.geojson" file**

# %%
response = s3_client.get_object(Bucket=bucket_name, Key='city-hex-polygons-8.geojson')
hex8 = gpd.read_file(response.get("Body"))
hex8
# Out:
#                 index  centroid_lat  centroid_lon  \
# 0     88ad361801fffff    -33.859427     18.677843
# 1     88ad361803fffff    -33.855696     18.668766
# 2     88ad361805fffff    -33.855263     18.685959
# 3     88ad361807fffff    -33.851532     18.676881
# 4     88ad361809fffff    -33.867322     18.678806
# ...               ...           ...           ...
# 3827  88ad369715fffff    -34.353404     18.479198
# 3828  88ad369717fffff    -34.349672     18.470112
# 3829  88ad369733fffff    -34.337717     18.477288
# 3830  88ad369739fffff    -34.349293     18.487330
# 3831  88ad36973bfffff    -34.345561     18.478243
#
#                                                geometry
# 0     POLYGON ((18.68119 -33.86330, 18.68357 -33.859...
# 1     POLYGON ((18.67211 -33.85957, 18.67450 -33.855...
# 2     POLYGON ((18.68931 -33.85914, 18.69169 -33.855...
# 3     POLYGON ((18.68023 -33.85541, 18.68261 -33.851...
# 4     POLYGON ((18.68215 -33.87120, 18.68454 -33.867...
# ...                                                 ...
# 3827  POLYGON ((18.48255 -34.35726, 18.48494 -34.353...
# 3828  POLYGON ((18.47346 -34.35353, 18.47585 -34.349...
# 3829  POLYGON ((18.48063 -34.34158, 18.48303 -34.337...
# 3830  POLYGON ((18.49068 -34.35315, 18.49307 -34.349...
# 3831  POLYGON ((18.48159 -34.34942, 18.48398 -34.345...
#
# [3832 rows x 4 columns]

# %%
hex8.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Specify date and name and export the file.
date_time=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
name=date_time+'_cpt8hex_geometries.geojson'

hex8.to_file(name, driver='GeoJSON')
# Out:
# C:\Users\ryanp\anaconda3\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,

# %% [markdown]
# **Read the "city-hex-polygons-8-10.geojson" file**

# %%
response = s3_client.get_object(Bucket=bucket_name, Key='city-hex-polygons-8-10.geojson')
hex8_10 = gpd.read_file(response.get("Body"))
hex8_10
# Out:
#                   index  centroid_lat  centroid_lon  resolution  \
# 0       88ad361801fffff    -33.859427     18.677843           8
# 1       88ad361803fffff    -33.855696     18.668766           8
# 2       88ad361805fffff    -33.855263     18.685959           8
# 3       88ad361807fffff    -33.851532     18.676881           8
# 4       88ad361809fffff    -33.867322     18.678806           8
# ...                 ...           ...           ...         ...
# 203835  8aad36973b6ffff    -34.348444     18.474894          10
# 203836  8aad36973b77fff    -34.348389     18.477354          10
# 203837  8aad36973b8ffff    -34.345507     18.480703          10
# 203838  8aad36973ba7fff    -34.347161     18.482137          10
# 203839  8aad36973baffff    -34.346627     18.480839          10
#
#                                                  geometry
# 0       POLYGON ((18.68119 -33.86330, 18.68357 -33.859...
# 1       POLYGON ((18.67211 -33.85957, 18.67450 -33.855...
# 2       POLYGON ((18.68931 -33.85914, 18.69169 -33.855...
# 3       POLYGON ((18.68023 -33.85541, 18.68261 -33.851...
# 4       POLYGON ((18.68215 -33.87120, 18.68454 -33.867...
# ...                                                   ...
# 203835  POLYGON ((18.47537 -34.34899, 18.47571 -34.348...
# 203836  POLYGON ((18.47783 -34.34894, 18.47817 -34.348...
# 203837  POLYGON ((18.48118 -34.34606, 18.48152 -34.345...
# 203838  POLYGON ((18.48262 -34.34771, 18.48296 -34.347...
# 203839  POLYGON ((18.48132 -34.34718, 18.48166 -34.346...
#
# [203840 rows x 5 columns]

# %%
hex8_10.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Specify date and name and export the file.
date_time=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
name=date_time+'_cpt8_10hex_geometries.geojson'

hex8_10.to_file(name, driver='GeoJSON')
# Out:
# C:\Users\ryanp\anaconda3\lib\site-packages\geopandas\io\file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
